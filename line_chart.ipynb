# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def min_max_scaling(data):
    min_val = min(data)
    max_val = max(data)
    return [(x - min_val) / (max_val - min_val) for x in data]


R = "None"

# %%
# # 1k
# R="1K"
# x = [0, 50, 67, 75, 80, 83, 86, 90]

# METEOR = min_max_scaling([0.1511, 0.1601, 0.1628, 0.1641, 0.1658, 0.1664, 0.1685, 0.1705])
# BLEU_2 = min_max_scaling([0.4605, 0.5009, 0.5049, 0.5098, 0.5140, 0.5173, 0.5168, 0.5217])
# BLEU_3 = min_max_scaling([0.3673, 0.3990, 0.4020, 0.4064, 0.4094, 0.4126, 0.4128, 0.4174])
# BLEU_4 = min_max_scaling([0.2924, 0.3166, 0.3189, 0.3225, 0.3248, 0.3274, 0.3282, 0.3325])
# COS_SIM = min_max_scaling([0.6225, 0.6317, 0.6330, 0.6364, 0.6366, 0.6382, 0.6416, 0.6453])

# # METEOR = ([0.1511, 0.1601, 0.1628, 0.1641, 0.1658, 0.1664, 0.1685, 0.1705])
# # BLEU_2 = ([0.4605, 0.5009, 0.5049, 0.5098, 0.5140, 0.5173, 0.5168, 0.5217])
# # BLEU_3 = ([0.3673, 0.3990, 0.4020, 0.4064, 0.4094, 0.4126, 0.4128, 0.4174])
# # BLEU_4 = ([0.2924, 0.3166, 0.3189, 0.3225, 0.3248, 0.3274, 0.3282, 0.3325])
# # COS_SIM = ([0.6225, 0.6317, 0.6330, 0.6364, 0.6366, 0.6382, 0.6416, 0.6453])

# %%
## 2k
# R="2K"
# x = [0, 50, 67, 75, 80, 83]

# METEOR = min_max_scaling([0.1543, 0.1622, 0.1676, 0.1708, 0.1714, 0.1730])
# BLEU_2 = min_max_scaling([0.4727, 0.4991, 0.5135, 0.5214, 0.5229, 0.5206])
# BLEU_3 = min_max_scaling([0.3781, 0.3981, 0.4103, 0.4175, 0.4185, 0.4177])
# BLEU_4 = min_max_scaling([0.3018, 0.3165, 0.3265, 0.3328, 0.3337, 0.3337])
# COS_SIM = min_max_scaling([0.6388, 0.6405, 0.6421, 0.6460, 0.6506, 0.6490])

# %%
l = [0.1671,
0.4824,
0.3906,
0.3158,
0.6664,
0.1709,
0.4923,
0.3973,
0.3200,
0.6603,
0.1722,
0.5050,
0.4070,
0.3272,
0.6595,
0.1731,
0.5063,
0.4082,
0.3282,
0.6603,
0.1747,
0.5182,
0.4171,
0.3346,
0.6574,
0.1725,
0.5192,
0.4166,
0.3332,
0.6556]









r = []
for i in range(6):
    tem = []
    for j in range(5):
        tem.append(l[i*5+j]) 
    r.append(tem)
np.array(r).T
# Out:
# array([[0.1671, 0.1709, 0.1722, 0.1731, 0.1747, 0.1725],
#        [0.4824, 0.4923, 0.505 , 0.5063, 0.5182, 0.5192],
#        [0.3906, 0.3973, 0.407 , 0.4082, 0.4171, 0.4166],
#        [0.3158, 0.32  , 0.3272, 0.3282, 0.3346, 0.3332],
#        [0.6664, 0.6603, 0.6595, 0.6603, 0.6574, 0.6556]])

# %%
# # 3k
# R="3K"
# x = [0, 50, 67, 70, 75, 80, 83]

# METEOR = min_max_scaling([0.1603, 0.1662, 0.1726, 0.1721, 0.1729, 0.1726, 0.1712])
# BLEU_2 = min_max_scaling([0.4836, 0.5047, 0.518 , 0.5171, 0.5196, 0.5203, 0.5147])
# BLEU_3 = min_max_scaling([0.3881, 0.4038, 0.4156, 0.4147, 0.4166, 0.4171, 0.4127])
# BLEU_4 = min_max_scaling([0.3108, 0.3219, 0.3319, 0.3311, 0.3328, 0.333 , 0.3297])
# COS_SIM = min_max_scaling([0.6426, 0.6445, 0.652 , 0.6518, 0.6528, 0.6506, 0.6505])

# %%
# # 4k
# R="4K"
# x = [0, 50, 67, 75, 80, 83]

# METEOR = min_max_scaling([0.1616, 0.1678, 0.171 , 0.1727, 0.1719, 0.1722])
# BLEU_2 = min_max_scaling([0.491 , 0.5111, 0.5178, 0.5171, 0.5182, 0.5167])
# BLEU_3 = min_max_scaling([0.3943, 0.4095, 0.415 , 0.4152, 0.4156, 0.4146])
# BLEU_4 = min_max_scaling([0.3159, 0.3268, 0.3314, 0.3321, 0.332 , 0.3313])
# COS_SIM = min_max_scaling([0.6517, 0.6483, 0.6491, 0.6533, 0.6508, 0.6508])

# %%
# # 5k
# R="5K"
# x = [0, 50, 67, 75]


# METEOR = min_max_scaling([0.1642, 0.1717, 0.1712, 0.1727])
# BLEU_2 = min_max_scaling([0.49  , 0.5163, 0.5176, 0.5177])
# BLEU_3 = min_max_scaling([0.3941, 0.4141, 0.4153, 0.4157])
# BLEU_4 = min_max_scaling([0.3164, 0.3309, 0.332 , 0.3327])
# COS_SIM = min_max_scaling([0.6545, 0.6516, 0.6516, 0.6525])

# %%
# # # 6k
# R="6K"
# x = [0, 40, 50, 67, 75]


# METEOR = min_max_scaling([0.1655, 0.1698, 0.1718, 0.1737, 0.1713])
# BLEU_2 = min_max_scaling([0.4837, 0.5077, 0.5155, 0.5176, 0.5187])
# BLEU_3 = min_max_scaling([0.3899, 0.408 , 0.4139, 0.416 , 0.416 ])
# BLEU_4 = min_max_scaling([0.3139, 0.3268, 0.331 , 0.3331, 0.3323])
# COS_SIM = min_max_scaling([0.6577, 0.6521, 0.653 , 0.6539, 0.6516])

# %%
# # 10k
R="10K"
x = [0, 17, 29, 33, 50, 64]

METEOR = min_max_scaling([0.1671, 0.1709, 0.1722, 0.1731, 0.1747, 0.1725])
BLEU_2 = min_max_scaling([0.4824, 0.4923, 0.505 , 0.5063, 0.5182, 0.5192])
BLEU_3 = min_max_scaling([0.3906, 0.3973, 0.407 , 0.4082, 0.4171, 0.4166])
BLEU_4 = min_max_scaling([0.3158, 0.32  , 0.3272, 0.3282, 0.3346, 0.3332])
COS_SIM = min_max_scaling([0.6664, 0.6603, 0.6595, 0.6603, 0.6574, 0.6556])

# %%
TITLE = f"CBR system with {R} real examples with diefferent generated ratio"

# %%
# # 10k

# x = [0, 10, 20, 30, 40, 50, 67, 70, 80, 90, 100]

# METEOR = min_max_scaling([0.1671, 0.1700, 0.1699, 0.1712, 0.1697, 0.1717, 0.1710, 0.1721, 0.1714, 0.1705, 0.1727])
# BLEU_2 = min_max_scaling([0.4824, 0.4941, 0.5005, 0.5186, 0.5077, 0.5163, 0.5178, 0.5171, 0.5229, 0.5217, 0.5210])
# BLEU_3 = min_max_scaling([0.3906, 0.3988, 0.4030, 0.4159, 0.4079, 0.4141, 0.4150, 0.4147, 0.4185, 0.4174, 0.4174])
# BLEU_4 = min_max_scaling([0.3158, 0.3214, 0.3238, 0.3323, 0.3267, 0.3309, 0.3314, 0.3311, 0.3337, 0.3325, 0.3327])
# COS_SIM = min_max_scaling([0.6664, 0.6631, 0.6584, 0.6515, 0.6521, 0.6516, 0.6491, 0.6518, 0.6506, 0.6453, 0.6442])

# METEOR = min_max_scaling([0.1671, 0.1700, 0.1699, 0.1711, 0.1698, 0.1717, 0.1710, 0.1721, 0.1714, 0.1705, 0.1727])
# BLEU_2 = min_max_scaling([0.4824, 0.4941, 0.5005, 0.5051, 0.5077, 0.5163, 0.5178, 0.5171, 0.5229, 0.5217, 0.5210])
# BLEU_3 = min_max_scaling([0.3906, 0.3988, 0.4030, 0.4064, 0.4080, 0.4141, 0.4150, 0.4147, 0.4185, 0.4174, 0.4174])
# BLEU_4 = min_max_scaling([0.3158, 0.3214, 0.3238, 0.3260, 0.3268, 0.3309, 0.3314, 0.3311, 0.3337, 0.3325, 0.3327])
# COS_SIM = min_max_scaling([0.6664, 0.6631, 0.6584, 0.6571, 0.6521, 0.6516, 0.6491, 0.6518, 0.6506, 0.6453, 0.6442])

# METEOR = ([0.1671, 0.1700, 0.1699, 0.1711, 0.1698, 0.1717, 0.1710, 0.1721, 0.1714, 0.1705, 0.1727])
# BLEU_2 = ([0.4824, 0.4941, 0.5005, 0.5051, 0.5077, 0.5163, 0.5178, 0.5171, 0.5229, 0.5217, 0.5210])
# BLEU_3 = ([0.3906, 0.3988, 0.4030, 0.4064, 0.4080, 0.4141, 0.4150, 0.4147, 0.4185, 0.4174, 0.4174])
# BLEU_4 = ([0.3158, 0.3214, 0.3238, 0.3260, 0.3268, 0.3309, 0.3314, 0.3311, 0.3337, 0.3325, 0.3327])
# COS_SIM = ([0.6664, 0.6631, 0.6584, 0.6571, 0.6521, 0.6516, 0.6491, 0.6518, 0.6506, 0.6453, 0.6442])

# TITLE = "Generated cases ration for 10 K size Case-Based"

# %%
plt.figure(figsize=(10, 6))

plt.plot(x, METEOR, label='Meteor')
plt.plot(x, BLEU_2, label='BLEU 2')
plt.plot(x, BLEU_3, label='BLEU 3')
plt.plot(x, BLEU_4, label='BLEU 4')
plt.plot(x, COS_SIM, label='Cosinus Similarity')
# plt.xscale('log')
# plt.xscale("symlog")

plt.legend(loc='lower right', fontsize='small')

plt.xlabel('Generated examples in Case-Based [%]')
plt.ylabel('Normalized scores')
plt.title(TITLE)

plt.show()

# %%
0.6664
0.6631
0.6603
0.6603
