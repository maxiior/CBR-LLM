# %%
import pandas as pd
import numpy as np
from helpers import validate_datestet

# %%
# df1 = pd.read_csv("small_validation_pe_2_results_p.csv")
# df2 = pd.read_csv("small_validation_pe_input.csv")

# df1 = pd.read_csv("small_validation_cbr_00_results.csv")
# df2 = pd.read_csv("small_validation_cbr_00_input.csv")

# df1 = pd.read_csv("cbr_augmentation_2_results.csv")
# df2 = pd.read_csv("cbr_augmentation_2_input.csv")

df1 = pd.read_csv("cbr_augmentation_3_results.csv")
df2 = pd.read_csv("cbr_augmentation_3_input.csv")

# df1 = pd.read_csv("__________________test_results.csv")
# df2 = pd.read_csv("test_input.csv")

# %%
validate_datestet(df1, df2)
# Out:
# True

# %%
df1[-10:]
# Out:
#                                                response  target_recipe
# 5303  In small saucepan mix together first 4 ingredi...         456835
# 5304  Cook beef in skillet until browned. Add onion....         324081
# 5305  Spray nonstick baking sheet with cooking spray...           2739
# 5306  Cook pasta. While it is cooking cut up cabbage...         353453
# 5307  Preheat oven to 350 degrees. Sprinkle fish wit...         255885
# 5308  Preheat oven to 425 degrees F (220 degrees C)....         122286
# 5309  In a large saucepan combine the soup, milk and...          53152
# 5310  Muddle lemongrass with ginger, then add sugar ...         458446
# 5311  Combine all ingredients except the chocolate a...          29087
# 5312  Preheat oven to 350 degrees. Wash and trim fat...         335954

# %%
df2[-10:]
# Out:
#                                                   input  \
# 5303  name: sausage with warm fruit ; ingredients: p...
# 5304  name: sweet and tangy sloppy joes ; ingredient...
# 5305  name: tilapia with garlic lime butter ; ingred...
# 5306  name: broccoli and noodles supreme ; ingredien...
# 5307  name: melon and grape medley ; ingredients: ca...
# 5308  name: strawberry cheesecake shake ; ingredient...
# 5309  name: nacho ordinary macaroni and cheese ; ing...
# 5310  name: home made velvet ginger lemonade ; ingre...
# 5311  name: hot bananas with rum and raisins ; ingre...
# 5312  name: virginia barbecue ; ingredients: boneles...
#
#                                              pe_recipes  target_recipe
# 5303  [25591, 46534, 244893, 26792, 386430, 28158, 1...         456835
# 5304  [211588, 8549, 223209, 262648, 72889, 296003, ...         324081
# 5305  [266965, 67675, 196276, 442947, 369198, 211823...           2739
# 5306  [122477, 24319, 141176, 219434, 37802, 186556,...         353453
# 5307  [280429, 108936, 294997, 451372, 346794, 81734...         255885
# 5308  [96576, 168903, 91147, 174102, 505988, 20537, ...         122286
# 5309  [158653, 22861, 36329, 4946, 40415, 522989, 29...          53152
# 5310  [443666, 454839, 10988, 94541, 155159, 29276, ...         458446
# 5311  [78526, 14228, 273148, 66437, 228096, 15700, 3...          29087
# 5312  [239187, 97962, 282437, 146686, 125765, 311020...         335954

# %%
df1
# Out:
#                                                response  target_recipe
# 0     Preheat oven to 350 degrees F (175 degrees C)....         236992
# 1     Mix together the butter, cream cheese and suga...         188944
# 2     Wash potato. Slice each in half. Mix herbs int...          74099
# 3     Dissolve gelatin in boiling water. Add sherbet...         230692
# 4     Crack egg into bag, add milk, salt & pepper to...         322782
# ...                                                 ...            ...
# 5308  Preheat oven to 425 degrees F (220 degrees C)....         122286
# 5309  In a large saucepan combine the soup, milk and...          53152
# 5310  Muddle lemongrass with ginger, then add sugar ...         458446
# 5311  Combine all ingredients except the chocolate a...          29087
# 5312  Preheat oven to 350 degrees. Wash and trim fat...         335954
#
# [5313 rows x 2 columns]

# %%
df2
# Out:
#                                                   input  \
# 0     name: peach royale ; ingredients: peaches, non...
# 1     name: lemon cheese spritz cookies ; ingredient...
# 2     name: garlic balsamic and rosemary roasted pot...
# 3     name: mandarin jell o salad ; ingredients: ora...
# 4     name: ham and tomato omelet ; ingredients: egg...
# ...                                                 ...
# 5308  name: strawberry cheesecake shake ; ingredient...
# 5309  name: nacho ordinary macaroni and cheese ; ing...
# 5310  name: home made velvet ginger lemonade ; ingre...
# 5311  name: hot bananas with rum and raisins ; ingre...
# 5312  name: virginia barbecue ; ingredients: boneles...
#
#                                              pe_recipes  target_recipe
# 0     [121301, 228096, 48200, 263245, 150402, 66945,...         236992
# 1     [442936, 143015, 5076, 82710, 148927, 79204, 4...         188944
# 2     [314112, 391034, 282682, 407555, 36307, 938, 8...          74099
# 3     [294997, 77909, 96460, 53502, 215089, 38845, 1...         230692
# 4     [482338, 345359, 289665, 292307, 455469, 20897...         322782
# ...                                                 ...            ...
# 5308  [96576, 168903, 91147, 174102, 505988, 20537, ...         122286
# 5309  [158653, 22861, 36329, 4946, 40415, 522989, 29...          53152
# 5310  [443666, 454839, 10988, 94541, 155159, 29276, ...         458446
# 5311  [78526, 14228, 273148, 66437, 228096, 15700, 3...          29087
# 5312  [239187, 97962, 282437, 146686, 125765, 311020...         335954
#
# [5313 rows x 3 columns]

# %%
# def test(df1:pd.DataFrame, df2:pd.DataFrame):
#     for (_, r1), (_, r2) in zip(df1.iterrows(), df2.iterrows()):
#         if r1["target_recipe"] != r1["target_recipe"]:
#             print()
#             print(r1)
#             print()
#             print(r2)
#             break
