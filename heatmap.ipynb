# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt


data = np.array([
    [0.6225, 0.6317, 0.6330, 0.6364, 0.6366, 0.6382],
    [0.6388, 0.6405, 0.6421, 0.6460, 0.6506, 0.6490],
    [0.6426, 0.6445, 0.652, 0.6528, 0.6506, 0.6505],
    [0.6517, 0.6483, 0.6491, 0.6533, 0.6508, 0.6508],
    [0.6545, 0.6516, 0.6516, 0.6525, float('nan'), float('nan')],
    [0.6577, 0.653 , 0.6539, 0.6516, float('nan'), float('nan')]
    
]).T
index_labels = [0, 50, 67, 75, 80, 83]
# index_labels.reverse()
# index_labels = ['50%', '40%', '30%', '20%', '10%', '0%']
columns_labels = [1, 2, 3, 4, 5, 6]


ax = sns.heatmap(data, linewidth=0.5, annot=True, xticklabels=columns_labels, yticklabels=index_labels)
plt.xlabel('Real examples in CBR system [10^3]')
plt.ylabel('Generated examples in Case-Based [%]')
plt.title('Adding generated to constant number of real examples\n[BERT embedding cosine similarity metric]')
plt.show()

# %%
# METEOR

import numpy as np
import seaborn as sns
import matplotlib.pylab as plt


data = np.array([
    [0.1511, 0.1601, 0.1628, 0.1641, 0.1658, 0.1664],
    [0.1543, 0.1622, 0.1676, 0.1708, 0.1714, 0.1730],
    [0.1603, 0.1662, 0.1726, 0.1729, 0.1726, 0.1712],
    [0.1616, 0.1678, 0.171 , 0.1727, 0.1719, 0.1722],
    [0.1642, 0.1717, 0.1712, 0.1727, float('nan'), float('nan')],
    [0.1655, 0.1718, 0.1737, 0.1713, float('nan'), float('nan')]
    
]).T
index_labels = [0, 50, 67, 75, 80, 83]
# index_labels.reverse()
# index_labels = ['50%', '40%', '30%', '20%', '10%', '0%']
columns_labels = [1, 2, 3, 4, 5, 6]


ax = sns.heatmap(data, linewidth=0.5, annot=True, xticklabels=columns_labels, yticklabels=index_labels)
plt.xlabel('Real examples in CBR system [10^3]')
plt.ylabel('Generated examples in Case-Based [%]')
plt.title('Adding generated to constant number of real examples\n[Meteor similarity metric]')
plt.show()
